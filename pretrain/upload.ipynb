# %%
# !huggingface-cli login
# Out:
# ^C

# %%
import transformers
import torch

# %%
model = torch.load('2022-06-18-17_06_13model.pt')

# %%
model.push_to_hub('t5-small-de-en-mt')
# Out:
# c:\Users\kevin\miniconda3\envs\python38\lib\site-packages\huggingface_hub\utils\_deprecation.py:39: FutureWarning: Pass token='t5-small-de-en-mt' as keyword args. From version 0.7 passing these as positional arguments will result in an error
#   warnings.warn(
# c:\Users\kevin\miniconda3\envs\python38\lib\site-packages\huggingface_hub\hf_api.py:596: FutureWarning: `create_repo` now takes `token` as an optional positional argument. Be sure to adapt your code!
#   warnings.warn(
# Cloning https://huggingface.co/Onlydrinkwater/t5-small-de-en-mt into local empty directory.
# Upload file pytorch_model.bin:  99%|█████████▉| 291M/294M [00:10<00:00, 32.8MB/s] To https://huggingface.co/Onlydrinkwater/t5-small-de-en-mt
#    72b6f51..908bb36  main -> main
#
# Upload file pytorch_model.bin: 100%|██████████| 294M/294M [00:11<00:00, 27.7MB/s]
# 'https://huggingface.co/Onlydrinkwater/t5-small-de-en-mt/commit/908bb3688db73af544531b64dad0135fe1a4cab1'

# %%
# Out:
# Downloading: 100%|██████████| 711/711 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 294M/294M [00:06<00:00, 49.7MB/s]
# Some weights of the model checkpoint at Onlydrinkwater/t5-small-de-en-mt were not used when initializing T5Model: ['lm_head.weight']
# - This IS expected if you are initializing T5Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing T5Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# T5Model(
#   (shared): Embedding(32128, 512)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
# ...
